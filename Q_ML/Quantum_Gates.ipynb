# %%
import qiskit
print(qiskit.__version__)
# Out:
# 2.5.0

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

# %%
import matplotlib
print(matplotlib.__version__)
print(matplotlib.__file__)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Aashka Warke\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\Aashka Warke\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\Aashka Warke\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Aashka Warke\AppData\Local\Temp\ipykernel_20436\3776609863.py", line 1, in <module>
#     import matplotlib
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "C:\Users\Aashka Warke\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import matplotlib
#       2 print(matplotlib.__version__)
#       3 print(matplotlib.__file__)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:129
#     125 from packaging.version import parse as parse_version
#     127 # cbook must import matplotlib only within function
#     128 # definitions, so it is safe to import from it here.
# --> 129 from . import _api, _version, cbook, _docstring, rcsetup
#     130 from matplotlib.cbook import sanitize_sequence
#     131 from matplotlib._api import MatplotlibDeprecationWarning
#
# File ~\anaconda3\Lib\site-packages\matplotlib\rcsetup.py:27
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:56
#      54 import matplotlib as mpl
#      55 import numpy as np
# ---> 56 from matplotlib import _api, _cm, cbook, scale
#      57 from ._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
#      60 class _ColorMapping(dict):
#
# File ~\anaconda3\Lib\site-packages\matplotlib\scale.py:22
#      20 import matplotlib as mpl
#      21 from matplotlib import _api, _docstring
# ---> 22 from matplotlib.ticker import (
#      23     NullFormatter, ScalarFormatter, LogFormatterSciNotation, LogitFormatter,
#      24     NullLocator, LogLocator, AutoLocator, AutoMinorLocator,
#      25     SymmetricalLogLocator, AsinhLocator, LogitLocator)
#      26 from matplotlib.transforms import Transform, IdentityTransform
#      29 class ScaleBase:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\ticker.py:138
#     136 import matplotlib as mpl
#     137 from matplotlib import _api, cbook
# --> 138 from matplotlib import transforms as mtransforms
#     140 _log = logging.getLogger(__name__)
#     142 __all__ = ('TickHelper', 'Formatter', 'FixedFormatter',
#     143            'NullFormatter', 'FuncFormatter', 'FormatStrFormatter',
#     144            'StrMethodFormatter', 'ScalarFormatter', 'LogFormatter',
#    (...)
#     150            'MultipleLocator', 'MaxNLocator', 'AutoMinorLocator',
#     151            'SymmetricalLogLocator', 'AsinhLocator', 'LogitLocator')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\transforms.py:49
#      46 from numpy.linalg import inv
#      48 from matplotlib import _api
# ---> 49 from matplotlib._path import (
#      50     affine_transform, count_bboxes_overlapping_bbox, update_path_extents)
#      51 from .path import Path
#      53 DEBUG = False
#
# ImportError: numpy.core.multiarray failed to import

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(2,2)


qc.x(0)
qc.measure([0,1],[0,1])

qc.draw("mpl")
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[8], line 9
#       6 qc.x(0)
#       7 qc.measure([0,1],[0,1])
# ----> 9 qc.draw("mpl")
#
# File ~\anaconda3\Lib\site-packages\qiskit\circuit\quantumcircuit.py:4048, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#    3903 r"""Draw the quantum circuit. Use the output parameter to choose the drawing format:
#    3904
#    3905 ``text``
#    (...)
#    4043        qc.draw(output='mpl', style={'backgroundcolor': '#EEEEEE'})
#    4044 """
#    4046 from qiskit.visualization import circuit_drawer
# -> 4048 return circuit_drawer(
#    4049     self,
#    4050     scale=scale,
#    4051     filename=filename,
#    4052     style=style,
#    4053     output=output,
#    4054     interactive=interactive,
#    4055     plot_barriers=plot_barriers,
#    4056     reverse_bits=reverse_bits,
#    4057     justify=justify,
#    4058     vertical_compression=vertical_compression,
#    4059     idle_wires=idle_wires,
#    4060     with_layout=with_layout,
#    4061     fold=fold,
#    4062     ax=ax,
#    4063     initial_state=initial_state,
#    4064     cregbundle=cregbundle,
#    4065     wire_order=wire_order,
#    4066     expr_len=expr_len,
#    4067     barrier_label_len=barrier_label_len,
#    4068     measure_arrows=measure_arrows,
#    4069 )
#
# File ~\anaconda3\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:368, in circuit_drawer(circuit, scale, filename, style, output, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     352     return _generate_latex_source(
#     353         circuit,
#     354         filename=filename,
#    (...)
#     365         barrier_label_len=barrier_label_len,
#     366     )
#     367 elif output == "mpl":
# --> 368     image = _matplotlib_circuit_drawer(
#     369         circuit,
#     370         scale=scale,
#     371         filename=filename,
#     372         style=style,
#     373         plot_barriers=plot_barriers,
#     374         reverse_bits=reverse_bits,
#     375         justify=justify,
#     376         idle_wires=idle_wires,
#     377         with_layout=with_layout,
#     378         fold=fold,
#     379         ax=ax,
#     380         initial_state=initial_state,
#     381         cregbundle=cregbundle,
#     382         wire_order=complete_wire_order,
#     383         expr_len=expr_len,
#     384         measure_arrows=measure_arrows,
#     385         barrier_label_len=barrier_label_len,
#     386     )
#     387 else:
#     388     raise VisualizationError(
#     389         f"Invalid output type {output} selected. The only valid choices "
#     390         "are text, latex, latex_source, and mpl"
#     391     )
#
# File ~\anaconda3\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:776, in _matplotlib_circuit_drawer(circuit, scale, filename, style, plot_barriers, reverse_bits, justify, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     773 if fold is None:
#     774     fold = 25
# --> 776 qcd = _matplotlib.MatplotlibDrawer(
#     777     qubits,
#     778     clbits,
#     779     nodes,
#     780     circuit,
#     781     scale=scale,
#     782     style=style,
#     783     reverse_bits=reverse_bits,
#     784     plot_barriers=plot_barriers,
#     785     fold=fold,
#     786     ax=ax,
#     787     initial_state=initial_state,
#     788     cregbundle=cregbundle,
#     789     with_layout=with_layout,
#     790     expr_len=expr_len,
#     791     barrier_label_len=barrier_label_len,
#     792     measure_arrows=measure_arrows,
#     793 )
#     794 return qcd.draw(filename)
#
# File ~\anaconda3\Lib\site-packages\qiskit\utils\classtools.py:111, in _WrappedMethod.__get__.<locals>.out(*args, **kwargs)
#     108 @functools.wraps(method)
#     109 def out(*args, **kwargs):
#     110     for callback in self._before:
# --> 111         callback.__get__(obj, objtype)(*args, **kwargs)
#     112     retval = method(*args, **kwargs)
#     113     for callback in self._after:
#
# File ~\anaconda3\Lib\site-packages\qiskit\utils\lazy_tester.py:42, in _RequireNow.__call__(self, *_args, **_kwargs)
#      41 def __call__(self, *_args, **_kwargs):
# ---> 42     self._tester.require_now(self._feature)
#
# File ~\anaconda3\Lib\site-packages\qiskit\utils\lazy_tester.py:222, in LazyDependencyManager.require_now(self, feature)
#     220 if self:
#     221     return
# --> 222 raise MissingOptionalLibraryError(
#     223     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     224 )
#
# MissingOptionalLibraryError: "The 'matplotlib' library is required to use 'MatplotlibDrawer'. You can install it with 'pip install matplotlib'."

# %%
]
# Out:
#   Cell In[10], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
